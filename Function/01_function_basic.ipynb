# %%
marks = [34,35,48]
total = 0

for i in range(len(marks)):
    total = total + marks[i]

print(total)
# Out:
# 117

# %%
def marksCalculator(marks):
    total = 0
    avg_marks =0
    for i in range(len(marks)):
        total = total + marks[i]
    avg_marks = total/len(marks)

    return total,avg_marks

# %%
marksCalculator([12,12,13,14])[0]=12
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 marksCalculator([12,12,13,14])[0]=12
#
# TypeError: 'tuple' object does not support item assignment

# %%
def describe_pet(animal_type, pet_name):
    """Describes a pet.
    eg 
    """
    print(f"I have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name}.")


describe_pet(animal_type='dog',pet_name='cat')
# Out:
# I have a dog.
# My dog's name is cat.

# %%
help(describe_pet)
# Out:
# Help on function describe_pet in module __main__:
#
# describe_pet(animal_type, pet_name)
#     Describes a pet.

# %%
print(1,2,3)
# Out:
# 1 2 3

# %%
def sum_all_numbers(*numbers):
    total =0
    for num in numbers:
        total +=num
    return total

# %%
sum_all_numbers(test = 1,test_1=2,3)
# Out:
# 6

# %%
def display_info(**details):
    for key, value in details.items():
        print({key:{value}})

# %%
display_info(name='bob',age=30,city="Mumbai",test='Soething')
# Out:
# {'name': {'bob'}}
# {'age': {30}}
# {'city': {'Mumbai'}}
# {'test': {'Soething'}}

# %%
def add(a, b):
    return a + b

add(2, 3)
# Out:
# 5

# %%
add = lambda x,y: x + y
add(2, 3)
# Out:
# 5

# %%
student =[{
    'name':'Alice',
    'age': 25,
    'courses': ['Math', 'Science']
},
{
    'name':'Bob',
    'age': 22,
    'courses': ['History', 'Math']
},
{
    'name':'Charlie',
    'age': 23,
    'courses': ['Biology', 'Math']
}
]


# without lamda function sorting based on age??

def get_age(student):
    return student['age']

sorted_students = sorted(student, key=get_age)
print(sorted_students)
# Out:
# [{'name': 'Bob', 'age': 22, 'courses': ['History', 'Math']}, {'name': 'Charlie', 'age': 23, 'courses': ['Biology', 'Math']}, {'name': 'Alice', 'age': 25, 'courses': ['Math', 'Science']}]

# %%
sorted(student,key=lambda student: student['name'])
# Out:
# [{'name': 'Alice', 'age': 25, 'courses': ['Math', 'Science']},
#  {'name': 'Bob', 'age': 22, 'courses': ['History', 'Math']},
#  {'name': 'Charlie', 'age': 23, 'courses': ['Biology', 'Math']}]

# %%
stock_price_pct_change = [0.5, -0.2, 0.3, -0.1, 0.4, 0.6]

# without lambda 
def get_stock_price_change(stock):
    result = []
    for price in stock:
        if price > 0:
            result.append("positive")
        else:
            result.append("negative")
    return result

get_stock_price_change(stock_price_pct_change)
# Out:
# ['positive', 'negative', 'positive', 'negative', 'positive', 'positive']

# %%
def get_stock_price_change(stock):
    if stock > 0:
        return stock

# %%
# without lambda function 
# list(filter(get_stock_price_change,stock_price_pct_change))
# official
list(filter(lambda x: x > 0, stock_price_pct_change))
# Out:
# [0.5, 0.3, 0.4, 0.6]

# %%
# help(filter)

# 1paramerter : function name 2: iterable
# eg.
def add(stocks):
    if stocks > 0:
        return "positive"
    else:
        return "negative"

list(filter(add, stock_price_pct_change))
# Out:
# [0.5, -0.2, 0.3, -0.1, 0.4, 0.6]

# %%
def calculate_order_total(price, quantity, discount=0):
    total = price * quantity
    return total - (total * discount)


def get_shipping_cost(total_weight):
    if total_weight <= 5:
        return 50.0, "Standard"
    elif total_weight < 20:
        return 100.0, "Express"
    else:
        return 200.0, "Next-Day"
    

def process_order(item_price, item_quantity, item_weight, discount=0):
    final_result = {
        'subtotal': calculate_order_total(item_price, item_quantity, discount),
        'shipping_cost': get_shipping_cost(item_weight)[0],
        'shipping_message': get_shipping_cost(item_weight)[1],
    }
    final_result['final_total'] = final_result['subtotal'] + final_result['shipping_cost']
    return final_result


# test
# print(calculate_order_total(100, 2))
# print(calculate_order_total(100, 2, 0.1))
# print(process_order(100, 2, 10))
print(process_order(100, 2, 10, 0.1))
# Out:
# {'subtotal': 180.0, 'shipping_cost': 100.0, 'shipping_message': 'Express', 'final_total': 280.0}

# %%
from sales import process_order
process_order(100, 2, 10, 0.1)
# Out:
# {'subtotal': 180.0,
#  'shipping_cost': 100.0,
#  'shipping_message': 'Express',
#  'final_total': 280.0}

# %%
def create_user_profile(username, email, age, city):
    user_profile = {
        'username': username,
        'email': email,
        'age': age,
        'city': city
    }
    return user_profile

# create_user_profile(username="john_doe", email="john@example.com", age=30, city="New York")
# Out:
# {'username': 'john_doe',
#  'email': 'john@example.com',
#  'age': 30,
#  'city': 'New York'}

# %%
def update_user_profile(user_id, **test):
    # Arbitrary number of keyword arguments
    print(user_id)
    # return the value
    for key, value in test.items():
        print(f"{key} : {value}")
    # return user_profile

update_user_profile(1, email="john_new@example.com", age=31, course="Python")
# Out:
# 1
# email : john_new@example.com
# age : 31
# course : Python

# %%
def generate_profile_id(*parts):
    return parts

generate_profile_id("john_doe", "NY", "USA")
# Out:
# ('john_doe', 'NY', 'USA')

# %% [markdown]
# # Case Study 2: User Profile Management
#
# ---
#
# **Scenario:**
# You are building a system to manage user profiles, which have varying attributes.
#
# ---
#
# ### ✅ Create Profile (Keyword Arguments)
# - **Define** a function `create_user_profile(username, email, age, city)`.
# - This function should **print** the user's profile details.
# - **Call it** using **keyword arguments in a mixed order** to demonstrate flexibility.
#
# ---
#
# ### ✅ Flexible Profile Update (`**kwargs`)
# - **Define** a function `update_user_profile(user_id, **updates)`.
# - It should:
#   - Take a `user_id`
#   - Accept an arbitrary number of keyword arguments representing profile updates (e.g., `city="New City", phone="123-456-7890"`)
#   - **Print** the `user_id`
#   - Iterate through the `updates` dictionary and print each key-value pair
# - **Test** with:
#   - `user_id=123, email="new@example.com", status="active"`
#   - `user_id=456, city="Paris"`
#
# ---
#
# ### ✅ Generate Profile ID (`*args`)
# - **Define** a function `generate_profile_id(*parts)`.
# - This function should:
#   - Accept an arbitrary number of string parts (e.g., first name, last name, date of birth)
#   - Concatenate them with a hyphen `-` to form a unique ID
#   - **Return** the generated ID
# - **Test** with:
#   - `("John", "Doe", "1990")`
#   - `("Jane", "Smith", "2000", "USA")`
#
# ---

# %% [markdown]
# # Case Study Questions: Functions
#
# ---
#
# ## 🛒 Case Study 1: E-commerce Order Processing
#
# **Scenario:**
# You are building part of an e-commerce system that calculates the total cost of an order, including discounts and shipping.
#
# ---
#
# ### ✅ Calculate Total Cost
# - **Define** a function `calculate_order_total(price, quantity)`.
# - The function should return the **subtotal** (`price * quantity`).
# - **Test** it with:
#   - `price=10.50, quantity=3`
#   - `price=50, quantity=1`
#
# ---
#
# ### ✅ Apply Discount (Default Argument)
# - Modify the `calculate_order_total` function to include an **optional** `discount_percentage` (defaulting to `0`).
# - The function should **subtract** the discount from the subtotal.
# - **Test** with:
#   - `price=100, quantity=2, discount_percentage=10`
#   - `price=100, quantity=2` (no discount)
#
# ---
#
# ### ✅ Calculate Shipping Cost (Multiple Return Values)
# - Define a function `get_shipping_cost(total_weight)`.
# - Rules:
#   - If `total_weight < 5 kg`, shipping is ₹50.
#   - If `5 ≤ total_weight ≤ 20 kg`, shipping is ₹100.
#   - If `total_weight > 20 kg`, shipping is ₹200.
# - Return **both**:
#   - `shipping_cost`
#   - `shipping_message` (e.g., "Standard Shipping" or "Heavy Item Shipping")
# - **Test** with:
#   - `total_weight=3`
#   - `total_weight=15`
#   - `total_weight=25`
#
# ---
#
# ### ✅ Final Order Summary (Combining Functions)
# - Create a main function `process_order(item_price, item_quantity, item_weight, discount=0)`.
# - This function should internally **call**:
#   - `calculate_order_total`
#   - `get_shipping_cost`
# - It should return:
#   - `final_total_amount`
#   - A **summary dictionary** containing:
#     ```python
#     {
#         'subtotal': ...,
#         'discount_applied': ...,
#         'shipping_cost': ...,
#         'shipping_message': ...,
#         'final_total': ...
#     }
#     ```
# - **Test** with:
#   - `item_price=250, item_quantity=4, item_weight=10, discount=5`
#
# ---
#
# 💡 _Tip: Save this file as `functions_case_study.md` for quick reference!_
#
# Would you like me to also generate **example code solutions** for these questions? Let me know! 🚀
