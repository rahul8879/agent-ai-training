# %% [markdown]
# ## Basic Of Python

# %%
a = '5'
type(a)
print(a)


# operation
float(a)+5
# Out:
# 5
# 10.0

# %% [markdown]
# This is my first code

# %%
# 10 student
# student1 = 'Rahul'
# student2 = 'Amit'
# student3 = 'Priya'
# student4 = 'Sneha'
# student5 = 'Rohit'
# student6 = 'Pooja'
# student7 = 'Karan'
# student8 = 'Neha'
# student9 = 'Vijay'
# student10 = 'Simran'

# list
students = ['Rahul', 'Amit', 'Priya', 'Sneha', 'Rohit', 'Pooja', 'Karan', 'Neha', 'Vijay', 'Simran']
print(students)

students.append('Sudheer')
print(students)
# Out:
# ['Rahul', 'Amit', 'Priya', 'Sneha', 'Rohit', 'Pooja', 'Karan', 'Neha', 'Vijay', 'Simran']
# ['Rahul', 'Amit', 'Priya', 'Sneha', 'Rohit', 'Pooja', 'Karan', 'Neha', 'Vijay', 'Simran', 'Sudheer']

# %%
help(students.append)
# Out:
# Help on built-in function append:
#
# append(object, /) method of builtins.list instance
#     Append object to the end of the list.
