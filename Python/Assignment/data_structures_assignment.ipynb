# %% [markdown]
# # Python Data Structures — Assignment
# ### Real-world examples from Retail, Finance & Interviews
#
# **Rules:**
# - Implement every function marked with `# TODO`.
# - Standard Python only — no external libraries.
# - Do **not** use `input()`. All data comes through function parameters.
# - Run the test cell below each task to check your answer.
#
# **Topics:** Strings · Lists · Dictionaries · Tuples · Sets

# %% [markdown]
# ---
# ## Task 1 — Clean Product Names (Strings)
#
# **Scenario:** You work at a retail company. Product names stored in the database are messy — they have extra spaces, mixed case, and special characters. You need to clean them before displaying on the website.
#
# **Function:** `clean_product_name(name: str) -> str`
#
# **Steps to apply (in order):**
# 1. Strip leading and trailing whitespace.
# 2. Convert to Title Case (first letter of each word is uppercase).
# 3. Replace multiple spaces between words with a single space.
#
# **Examples:**
# ```python
# clean_product_name("  apple   juice  ")  ->  "Apple Juice"
# clean_product_name("WHOLE MILK")         ->  "Whole Milk"
# clean_product_name(" basmati   rice ")   ->  "Basmati Rice"
# ```

# %%
def clean_product_name(name: str) -> str:
    # TODO: implement
    pass

# %%
# --- Tests ---
assert clean_product_name("  apple   juice  ") == "Apple Juice"
assert clean_product_name("WHOLE MILK") == "Whole Milk"
assert clean_product_name(" basmati   rice ") == "Basmati Rice"
assert clean_product_name("sugar") == "Sugar"
print("Task 1 passed!")

# %% [markdown]
# ---
# ## Task 2 — Shopping Cart Operations (Lists)
#
# **Scenario:** Build a simple shopping cart that supports adding items, removing items, and calculating the total bill.
#
# **Functions:**
#
# ### 2a. `add_item(cart: list, item: str) -> list`
# - Add `item` to the cart and return the updated cart.
#
# ### 2b. `remove_item(cart: list, item: str) -> list`
# - Remove the first occurrence of `item` from the cart.
# - If the item is not in the cart, return the cart unchanged.
#
# ### 2c. `total_bill(cart: list, prices: dict) -> float`
# - `prices` is a dict like `{"milk": 50, "bread": 30}`.
# - Return the total cost of all items in the cart.
# - If an item has no price in `prices`, treat its price as `0`.
#
# **Example:**
# ```python
# cart = []
# cart = add_item(cart, "milk")    # ["milk"]
# cart = add_item(cart, "bread")   # ["milk", "bread"]
# cart = add_item(cart, "milk")    # ["milk", "bread", "milk"]
# cart = remove_item(cart, "milk") # ["bread", "milk"]  <- removes first occurrence
# total_bill(cart, {"milk": 50, "bread": 30})  # -> 80.0
# ```

# %%
def add_item(cart: list, item: str) -> list:
    # TODO: implement
    pass


def remove_item(cart: list, item: str) -> list:
    # TODO: implement
    pass


def total_bill(cart: list, prices: dict) -> float:
    # TODO: implement
    pass

# %%
# --- Tests ---
cart = []
cart = add_item(cart, "milk")
cart = add_item(cart, "bread")
cart = add_item(cart, "milk")
assert cart == ["milk", "bread", "milk"]

cart = remove_item(cart, "milk")
assert cart == ["bread", "milk"]

# removing non-existent item should not crash
cart = remove_item(cart, "eggs")
assert cart == ["bread", "milk"]

prices = {"milk": 50, "bread": 30}
assert total_bill(cart, prices) == 80.0
assert total_bill(["milk", "unknown_item"], prices) == 50.0

print("Task 2 passed! Bill: Rs.", total_bill(cart, prices))

# %% [markdown]
# ---
# ## Task 3 — Weekly Sales Analysis (Lists + Slicing)
#
# **Scenario:** A retail store records daily sales for a week (7 values). The manager wants a quick summary.
#
# **Functions:**
#
# ### 3a. `average_sales(sales: list) -> float`
# - Return the average daily sale rounded to 2 decimal places.
#
# ### 3b. `best_and_worst_day(sales: list) -> tuple`
# - Return `(best_day, worst_day)` as a tuple where each is a **1-indexed** day number.
#
# ### 3c. `above_average_days(sales: list) -> list`
# - Return a list of **1-indexed** day numbers where sales were strictly above the average.
#
# **Example:**
# ```python
# sales = [5000, 7000, 4500, 8000, 6000, 9000, 3000]
# average_sales(sales)          # -> 6071.43
# best_and_worst_day(sales)     # -> (6, 7)
# above_average_days(sales)     # -> [2, 4, 5, 6]
# ```

# %%
def average_sales(sales: list) -> float:
    # TODO: implement
    pass


def best_and_worst_day(sales: list) -> tuple:
    # TODO: implement
    pass


def above_average_days(sales: list) -> list:
    # TODO: implement
    pass

# %%
# --- Tests ---
sales = [5000, 7000, 4500, 8000, 6000, 9000, 3000]

assert average_sales(sales) == 6071.43
assert best_and_worst_day(sales) == (6, 7)
assert above_average_days(sales) == [2, 4, 6]

print("Task 3 passed!")
print("Average:", average_sales(sales))
print("Best day / Worst day:", best_and_worst_day(sales))
print("Days above average:", above_average_days(sales))

# %% [markdown]
# ---
# ## Task 4 — Customer Profile Manager (Dictionaries)
#
# **Scenario:** A bank stores customer profiles as dictionaries. You need functions to manage and query these profiles.
#
# **Functions:**
#
# ### 4a. `create_profile(name: str, age: int, balance: float) -> dict`
# - Return a dict with keys `"name"`, `"age"`, `"balance"`, and `"transactions"` (an empty list).
#
# ### 4b. `deposit(profile: dict, amount: float) -> dict`
# - Add `amount` to `"balance"`.
# - Append `+amount` (as a float) to `"transactions"`.
# - Return the updated profile.
#
# ### 4c. `withdraw(profile: dict, amount: float) -> dict`
# - If balance is sufficient, subtract `amount` from `"balance"` and append `-amount` to `"transactions"`.
# - If balance is insufficient, do **not** change the profile — print `"Insufficient funds"`.
# - Return the profile.
#
# ### 4d. `account_summary(profile: dict) -> str`
# - Return a string in this exact format:
#   `"Name: Rahul | Balance: Rs.1500.0 | Transactions: 3"`
#
# **Example:**
# ```python
# p = create_profile("Rahul", 28, 1000.0)
# p = deposit(p, 500.0)
# p = withdraw(p, 200.0)
# account_summary(p)  # "Name: Rahul | Balance: Rs.1300.0 | Transactions: 2"
# ```

# %%
def create_profile(name: str, age: int, balance: float) -> dict:
    # TODO: implement
    pass


def deposit(profile: dict, amount: float) -> dict:
    # TODO: implement
    pass


def withdraw(profile: dict, amount: float) -> dict:
    # TODO: implement
    pass


def account_summary(profile: dict) -> str:
    # TODO: implement
    pass

# %%
# --- Tests ---
p = create_profile("Rahul", 28, 1000.0)
assert p == {"name": "Rahul", "age": 28, "balance": 1000.0, "transactions": []}

p = deposit(p, 500.0)
assert p["balance"] == 1500.0
assert p["transactions"] == [500.0]

p = withdraw(p, 200.0)
assert p["balance"] == 1300.0
assert p["transactions"] == [500.0, -200.0]

p = withdraw(p, 9999.0)   # should print "Insufficient funds" and not change balance
assert p["balance"] == 1300.0

summary = account_summary(p)
assert summary == "Name: Rahul | Balance: Rs.1300.0 | Transactions: 2", f"Got: {summary}"

print("Task 4 passed!")
print(summary)

# %% [markdown]
# ---
# ## Task 5 — Duplicate Order Detection (Sets)
#
# **Scenario:** An e-commerce platform receives a batch of order IDs. Due to a system bug, some orders were recorded twice. You need to find the duplicates and also the unique orders.
#
# **Functions:**
#
# ### 5a. `find_duplicates(order_ids: list) -> set`
# - Return the set of order IDs that appear **more than once**.
#
# ### 5b. `unique_orders(order_ids: list) -> list`
# - Return a list of order IDs with duplicates removed, keeping **original order** of first occurrence.
#
# ### 5c. `orders_in_both(batch_a: list, batch_b: list) -> set`
# - Return order IDs that appear in **both** batches (use set intersection).
#
# **Example:**
# ```python
# orders = ["ORD1", "ORD2", "ORD1", "ORD3", "ORD2", "ORD4"]
# find_duplicates(orders)   # -> {"ORD1", "ORD2"}
# unique_orders(orders)     # -> ["ORD1", "ORD2", "ORD3", "ORD4"]
# ```

# %%
def find_duplicates(order_ids: list) -> set:
    # TODO: implement
    pass


def unique_orders(order_ids: list) -> list:
    # TODO: implement
    pass


def orders_in_both(batch_a: list, batch_b: list) -> set:
    # TODO: implement
    pass

# %%
# --- Tests ---
orders = ["ORD1", "ORD2", "ORD1", "ORD3", "ORD2", "ORD4"]

assert find_duplicates(orders) == {"ORD1", "ORD2"}
assert unique_orders(orders) == ["ORD1", "ORD2", "ORD3", "ORD4"]

batch_a = ["ORD1", "ORD2", "ORD5"]
batch_b = ["ORD2", "ORD3", "ORD5"]
assert orders_in_both(batch_a, batch_b) == {"ORD2", "ORD5"}

print("Task 5 passed!")
print("Duplicates:", find_duplicates(orders))
print("Unique:", unique_orders(orders))

# %% [markdown]
# ---
# ## Task 6 — Monthly Expense Tracker (Dicts + Comprehensions)
#
# **Scenario:** You have a list of transactions for the month. Each transaction is a dict with a `"category"` and `"amount"`. Find total spending per category.
#
# **Functions:**
#
# ### 6a. `spending_by_category(transactions: list) -> dict`
# - Return a dict `{category: total_amount}` summing amounts for each category.
#
# ### 6b. `top_spending_category(transactions: list) -> str`
# - Return the name of the category with the highest total spending.
#
# ### 6c. `filter_transactions(transactions: list, min_amount: float) -> list`
# - Return a list of transactions where `amount >= min_amount`.
# - Use a **list comprehension**.
#
# **Example:**
# ```python
# transactions = [
#     {"category": "Food",     "amount": 500},
#     {"category": "Travel",   "amount": 1200},
#     {"category": "Food",     "amount": 300},
#     {"category": "Shopping", "amount": 800},
# ]
# spending_by_category(transactions)   # {"Food": 800, "Travel": 1200, "Shopping": 800}
# top_spending_category(transactions)  # "Travel"
# filter_transactions(transactions, 500)  # transactions with amount >= 500
# ```

# %%
def spending_by_category(transactions: list) -> dict:
    # TODO: implement
    pass


def top_spending_category(transactions: list) -> str:
    # TODO: implement
    pass


def filter_transactions(transactions: list, min_amount: float) -> list:
    # TODO: use a list comprehension
    pass

# %%
# --- Tests ---
transactions = [
    {"category": "Food",     "amount": 500},
    {"category": "Travel",   "amount": 1200},
    {"category": "Food",     "amount": 300},
    {"category": "Shopping", "amount": 800},
    {"category": "Travel",   "amount": 200},
]

assert spending_by_category(transactions) == {"Food": 800, "Travel": 1400, "Shopping": 800}
assert top_spending_category(transactions) == "Travel"

big_spends = filter_transactions(transactions, 500)
assert len(big_spends) == 3
assert all(t["amount"] >= 500 for t in big_spends)

print("Task 6 passed!")
print("By category:", spending_by_category(transactions))
print("Top category:", top_spending_category(transactions))

# %% [markdown]
# ---
# ## Task 7 — Stock Price Record (Tuples)
#
# **Scenario:** Stock data is stored as immutable records — a tuple of `(symbol, open, high, low, close)`. You will write functions to analyse these records.
#
# **Functions:**
#
# ### 7a. `price_range(record: tuple) -> float`
# - Return `high - low` (the day's trading range).
#
# ### 7b. `is_bullish(record: tuple) -> bool`
# - Return `True` if `close > open` (price went up), else `False`.
#
# ### 7c. `best_performing_stock(records: list) -> str`
# - `records` is a list of such tuples.
# - Return the **symbol** of the stock with the highest `(close - open)` gain.
#
# **Tuple format:** `(symbol, open, high, low, close)`
#
# **Example:**
# ```python
# record = ("INFY", 1500, 1560, 1480, 1540)
# price_range(record)   # -> 80
# is_bullish(record)    # -> True  (1540 > 1500)
# ```

# %%
def price_range(record: tuple) -> float:
    # record = (symbol, open, high, low, close)
    # TODO: implement
    pass


def is_bullish(record: tuple) -> bool:
    # TODO: implement
    pass


def best_performing_stock(records: list) -> str:
    # TODO: implement
    pass

# %%
# --- Tests ---
infy  = ("INFY",  1500, 1560, 1480, 1540)  # gain = +40
tcs   = ("TCS",   3200, 3300, 3150, 3280)  # gain = +80
wipro = ("WIPRO",  400,  410,  390,  395)  # gain = -5

assert price_range(infy) == 80
assert price_range(tcs)  == 150

assert is_bullish(infy)  == True
assert is_bullish(wipro) == False

assert best_performing_stock([infy, tcs, wipro]) == "TCS"

print("Task 7 passed!")
print("Best stock:", best_performing_stock([infy, tcs, wipro]))

# %% [markdown]
# ---
# ## Task 8 — Classic Interview Problems (Strings)
#
# These are frequently asked in Python/data engineer interviews.
#
# ### 8a. `is_palindrome(text: str) -> bool`
# - Return `True` if `text` reads the same forwards and backwards.
# - Ignore case. Ignore spaces.
# - `"Race Car"` → `True`,  `"hello"` → `False`
#
# ### 8b. `is_anagram(word1: str, word2: str) -> bool`
# - Return `True` if `word1` and `word2` are anagrams (contain the same characters in any order).
# - Ignore case.
# - `"listen"`, `"silent"` → `True`
#
# ### 8c. `count_vowels(text: str) -> int`
# - Return the count of vowels (`a e i o u`) in `text` (case-insensitive).
#
# ### 8d. `reverse_words(sentence: str) -> str`
# - Reverse the **order of words** in the sentence (not the letters).
# - `"Hello World"` → `"World Hello"`

# %%
def is_palindrome(text: str) -> bool:
    # TODO: implement
    pass


def is_anagram(word1: str, word2: str) -> bool:
    # TODO: implement
    pass


def count_vowels(text: str) -> int:
    # TODO: implement
    pass


def reverse_words(sentence: str) -> str:
    # TODO: implement
    pass

# %%
# --- Tests ---
assert is_palindrome("Race Car") == True
assert is_palindrome("madam")    == True
assert is_palindrome("hello")    == False

assert is_anagram("listen", "silent") == True
assert is_anagram("Triangle", "Integral") == True
assert is_anagram("hello", "world")   == False

assert count_vowels("Hello World") == 3
assert count_vowels("AEIOU")       == 5
assert count_vowels("gym")         == 0

assert reverse_words("Hello World")      == "World Hello"
assert reverse_words("I love Python")    == "Python love I"

print("Task 8 passed!")

# %% [markdown]
# ---
# ## Bonus — Product Discount Report (Dicts + List Comprehensions)
#
# **Scenario:** A retail manager wants to apply a discount to products above a certain price and generate a report.
#
# **Function:** `discount_report(products: list, min_price: float, discount_pct: float) -> list`
#
# - `products` is a list of dicts: `{"name": str, "price": float}`.
# - Apply `discount_pct`% discount to products with `price >= min_price`.
# - Return a **new list** of dicts with `"name"`, original `"price"`, and `"discounted_price"` (rounded to 2 decimal places).
# - Products below `min_price` should also appear in the result with `discounted_price == price`.
# - Use a **list comprehension** or dict comprehension.
#
# **Example:**
# ```python
# products = [
#     {"name": "TV",     "price": 30000},
#     {"name": "Phone",  "price": 15000},
#     {"name": "Pen",    "price": 20},
# ]
# discount_report(products, min_price=1000, discount_pct=10)
# # [
# #   {"name": "TV",    "price": 30000, "discounted_price": 27000.0},
# #   {"name": "Phone", "price": 15000, "discounted_price": 13500.0},
# #   {"name": "Pen",   "price": 20,    "discounted_price": 20},
# # ]
# ```

# %%
def discount_report(products: list, min_price: float, discount_pct: float) -> list:
    # TODO: implement using a list comprehension
    pass

# %%
# --- Tests ---
products = [
    {"name": "TV",    "price": 30000},
    {"name": "Phone", "price": 15000},
    {"name": "Pen",   "price": 20},
]
report = discount_report(products, min_price=1000, discount_pct=10)

assert report[0]["discounted_price"] == 27000.0
assert report[1]["discounted_price"] == 13500.0
assert report[2]["discounted_price"] == 20        # no discount applied
assert len(report) == 3

print("Bonus passed!")
for item in report:
    print(f"  {item['name']:10} original: {item['price']:>8}  discounted: {item['discounted_price']:>8}")
